# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="whitegrid", color_codes=True)
# %matplotlib inline

# %%
df = pd.read_csv('VGSales.csv')

# %%
df
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
rmv_tbd = df.loc[df['User_Score'] == 'tbd'].index
#df.loc[df['User_Score'] == 'tbd']
rmv_tbd
# Out:
# Int64Index([  119,   301,   520,   645,   657,   718,   726,   821,   881,
#              1047,
#             ...
#             16654, 16659, 16673, 16676, 16692, 16699, 16701, 16702, 16708,
#             16710],
#            dtype='int64', length=2425)

# %%
a=df.set_value(rmv_tbd, 'User_Score', np.nan)
a
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %% [markdown]
# <b> User Score should not be object type

# %%
#User Score should not be object type
a = pd.Series(df['User_Score'])
type(a)
# Out:
# pandas.core.series.Series

# %%
b = pd.to_numeric(a)
b[:5]
# Out:
# 0    8.0
# 1    NaN
# 2    8.3
# 3    8.0
# 4    NaN
# Name: User_Score, dtype: float64

# %%
df['User_Score'] = b

# %%
df.dtypes #sanity check
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %% [markdown]
# <b> Checking for missing values in sales colunms </b>
# <br> None are found

# %%
print(df['Global_Sales'].isnull().sum(), df['NA_Sales'].isnull().sum(), df['EU_Sales'].isnull().sum(), df['JP_Sales'].isnull().sum(), df['Other_Sales'].isnull().sum())
#no NaN in sales data
# Out:
# 0 0 0 0 0

# %%
print(min(df['Year_of_Release']))
print(max(df['Year_of_Release']))
#given that this datset was collected on or before December 31, a value in the year 2020 is impossible.
#For this reason, this value will be removed.
# Out:
# 1980.0
# 2020.0

# %%
df.loc[df['Year_of_Release'] == 2020]
#The index of year = 2020 is 5936
# Out:
#                         Name Platform  Year_of_Release       Genre Publisher  \
# 5936  Imagine: Makeup Artist       DS           2020.0  Simulation   Ubisoft
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 5936      0.27       0.0       0.0         0.02          0.29           NaN
#
#       Critic_Count  User_Score  User_Count Developer Rating
# 5936           NaN         NaN         NaN   Ubisoft      E

# %%
df.set_value(5936, 'Year_of_Release', np.nan)
#Removed 2020 from YoR
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
df.loc[df['Year_of_Release'] == 2017]
# Out:
#                                                    Name Platform  \
# 14086  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16222  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16385                  Brothers Conflict: Precious Baby      PSV
#
#        Year_of_Release         Genre     Publisher  NA_Sales  EU_Sales  \
# 14086           2017.0  Role-Playing          Sega       0.0       0.0
# 16222           2017.0  Role-Playing          Sega       0.0       0.0
# 16385           2017.0        Action  Idea Factory       0.0       0.0
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 14086      0.04          0.0          0.04           NaN           NaN
# 16222      0.01          0.0          0.01           NaN           NaN
# 16385      0.01          0.0          0.01           NaN           NaN
#
#        User_Score  User_Count Developer Rating
# 14086         NaN         NaN       NaN    NaN
# ...

# %%
tmp = [14086, 16222, 16385]

# %%
df.set_value(tmp, 'Year_of_Release', np.nan)
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
df[df['Year_of_Release'] > 2016]
#Checking to see that all YoR greater than 2016 have been removed
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating]
# Index: []

# %%
#Distribution of Year when games were produced
df.hist('Year_of_Release')
plt.title('Counts of Games x Year of Release')
plt.ylabel('Year of Release')
plt.ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# <b> Global Sales by Year

# %%
yr_glob_sales = pd.DataFrame(df.groupby(['Year_of_Release'])['Global_Sales'].sum())

# %%
yr_glob_sales.plot(kind = 'bar', title = 'Global Sales by Genre', figsize = (20,8), rot = 45)
plt.ylabel('Global_Sales')
plt.xlabel('Year of Release')
#Here we see that from 1995 onwards, there is an explosion of video games being made. [1]
#2008/2009 marked the peak of video gaming world.
#Decline in VGsales is evident from 2009 onwards. This does not mean that VGs have gone out of style.[2]
# Out:
# Text(0.5,0,'Year of Release')

# %% [markdown]
# [1] The 1990s were a decade of marked innovation in video gaming. It was a decade of transition from sprite-based graphics to full-fledged 3D graphics and it gave rise to several genres of video games including, but not limited to, the first person shooter, real-time strategy, survival horror, and MMO. Handheld gaming began to become more popular throughout the decade[citation needed], thanks in part to the release of the Game Boy[citation needed]. Arcade games, although still relatively popular in the early 1990s, begin a decline as home consoles become more common.<br>
# Wikipedia: 1990s in video gaming<br>
#
# [2]"The dynamics of games content purchasing changed dramatically in 2010 with options ranging from the physical product to digital downloads on connected devices as well as in-store digital kiosks,” said Anita Frazier, industry analyst for The NPD Group. “The increasing number of ways to acquire the content has allowed the industry to maintain total consumer spend on content as compared to 2009, and we should expect 2011 to be a growth year in the games industry as the consumer demand for gaming continues to evolve.”<br>
# https://www.cnbc.com/id/41062675<br>
#
# https://www.statista.com/statistics/190225/digital-and-physical-game-sales-in-the-us-since-2009/

# %% [markdown]
# <b> Distribution of Sales by Region

# %%
#Create boxplot to view distribution of numeric data
box_plot = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
sns.boxplot(data = box_plot, orient = 'h');
plt.title('Sales Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Sales (in millions)')
# Out:
# Text(0,0.5,'Sales (in millions)')

# %% [markdown]
# Here, we can see that the mean, min, and max figures are rather low with many outliers.

# %% [markdown]
# <b> Region Wise Sales

# %%
yr_region_sales = df.groupby('Year_of_Release')[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum()
yr_region_sales.plot(kind = 'bar', stacked = True, figsize = (18,8), title = "Region Wise Sales")
plt.xlabel("Year of Release")
plt.ylabel("Global Sales (in millions)")
# Out:
# Text(0,0.5,'Global Sales (in millions)')

# %% [markdown]
# <b> VGSales by Genre

# %%
gen_counts = df['Genre'].value_counts()

# %%
gen_counts.plot(kind = 'bar', figsize = (12,6), rot = 'horizontal', title = 'Game Genres from Most Popular to Least Popular')
plt.ylabel('Counts')
plt.xlabel('Genres')
# Out:
# Text(0.5,0,'Genres')

# %% [markdown]
# Need to create a df with 2 levels of indexes, YoR and Genre, and see the Global Sales

# %%
yr_gen_glob_sales = pd.DataFrame(df.groupby(['Year_of_Release','Genre'])['Global_Sales'].sum())

# %%
yr_gen_glob_sales = yr_gen_glob_sales.reset_index()

# %%
yr_gen_glob_sales.pivot(index ='Year_of_Release', columns = 'Genre', values = 'Global_Sales').plot(kind = 'bar', stacked = True, title = 'Global Sales by Genre', figsize = (20,8))
plt.ylabel('Global_Sales')
plt.xlabel('Year of Release')
# Out:
# Text(0.5,0,'Year of Release')

# %% [markdown]
# Another thing I could do to make this clearer is to take only the top 3 and the bottom 3 to compare.

# %%
act = yr_gen_glob_sales[yr_gen_glob_sales['Genre'] == 'Action']
puz = yr_gen_glob_sales[yr_gen_glob_sales['Genre'] == 'Puzzle']
fight = yr_gen_glob_sales[yr_gen_glob_sales['Genre'] == 'Fighting']
sim = yr_gen_glob_sales[yr_gen_glob_sales['Genre'] == 'Simulation']
sport = yr_gen_glob_sales[yr_gen_glob_sales['Genre'] == 'Sports']
strategy = yr_gen_glob_sales[yr_gen_glob_sales['Genre'] == 'Strategy']

# %%
top3_bottom3 = act.append(puz).append(fight).append(sim).append(sport).append(strategy)

# %%
top3_bottom3.pivot(index ='Year_of_Release', columns = 'Genre', values = 'Global_Sales').plot(kind = 'line', title = 'Global Sales by Genre', figsize = (18,8))
plt.ylabel('Global_Sales')
plt.xlabel('Year of Release')
# Out:
# Text(0.5,0,'Year of Release')

# %% [markdown]
# Some games did not exist until late 1980s and early 1990s: simulation, strategy, fighting. This is due to the fact that the technology for these types of games did not become commercially available until then. <br>
# The pattern of this graph matches closely with the one above - this is to be expected.

# %% [markdown]
# <b> Global Sales by Publisher

# %% [markdown]
# Top 10 Publishers

# %%
G_Sales_Publisher = df.groupby('Publisher')['Global_Sales'].sum().sort_values(ascending = False).head(10)
G_Sales_Publisher.plot(kind = 'bar', title = 'Sales by Top 10 Publishers')
plt.xlabel('Publisher')
plt.ylabel('n')
# Out:
# Text(0,0.5,'n')

# %% [markdown]
# Publishers with highest global sales are: Nintendo, Electronic Arts, Activision, Sony Computer Entertainment, Ubisoft. <br>
# Nintendo and EA takes the lead by far.

# %%
#Perhaps producing popular genres is the way to to the top of the VGSales leaderboard?
df.groupby(['Publisher', 'Genre'])['Genre'].count().sort_values(ascending = False).head(10)
#While many of the publishers who appear hear are also on the list above, the relationship is more complicated.
# Out:
# Publisher                               Genre
# Electronic Arts                         Sports     560
# Activision                              Action     311
# Konami Digital Entertainment            Sports     281
# Namco Bandai Games                      Action     251
# Ubisoft                                 Action     198
# THQ                                     Action     194
# Electronic Arts                         Action     183
# Warner Bros. Interactive Entertainment  Action     169
# Activision                              Shooter    162
# Electronic Arts                         Racing     159
# Name: Genre, dtype: int64

# %% [markdown]
# <b> Number of games by Rating Category

# %%
df['Rating'].value_counts().plot(kind = 'bar', title = 'Counts of Rating')
plt.ylabel('n')
plt.xlabel('Rating Categories')
# Out:
# Text(0.5,0,'Rating Categories')

# %% [markdown]
# <b> Distribution of Global Sales across Genres and Rating

# %%
df.groupby('Rating')['Global_Sales'].sum().plot(kind = 'bar', title = 'Global Sales x Rating Category')
plt.ylabel('Global Sales')
plt.xlabel('Rating')
# Out:
# Text(0.5,0,'Rating')

# %%
Genre_Rating_GSales = df[['Genre', 'Rating', 'Global_Sales']]
Genre_Rating_GSales.head()
# Out:
#           Genre Rating  Global_Sales
# 0        Sports      E         82.53
# 1      Platform    NaN         40.24
# 2        Racing      E         35.52
# 3        Sports      E         32.77
# 4  Role-Playing    NaN         31.37

# %%
Genre_Rating_GSales['log(Global_Sales)'] = Genre_Rating_GSales['Global_Sales'].apply(lambda x: np.log(x+1)
)
# Out:
# /Users/cherylto/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Genre_Rating_GSales.head()
# Out:
#           Genre Rating  Global_Sales  log(Global_Sales)
# 0        Sports      E         82.53           4.425206
# 1      Platform    NaN         40.24           3.719409
# 2        Racing      E         35.52           3.597860
# 3        Sports      E         32.77           3.519573
# 4  Role-Playing    NaN         31.37           3.477232

# %%
Genre_Rating_GSales = Genre_Rating_GSales.drop('Global_Sales', axis = 1)

# %%
tmp2 = pd.pivot_table(Genre_Rating_GSales, values = 'log(Global_Sales)', index = 'Genre', columns = 'Rating')
tmp2
# Out:
# Rating              AO         E      E10+        EC       K-A         M  \
# Genre
# Action        1.081805  0.308274  0.315717  0.371564       NaN  0.487770
# Adventure          NaN  0.262888  0.151962  0.164220       NaN  0.257294
# Fighting           NaN  0.125079  0.201580       NaN       NaN  0.383409
# Misc               NaN  0.312981  0.375347  0.171326  1.071584  0.224363
# Platform           NaN  0.429493  0.301995       NaN       NaN  0.409096
# Puzzle             NaN  0.192397  0.288407       NaN       NaN       NaN
# Racing             NaN  0.312852  0.382697       NaN       NaN  0.205947
# Role-Playing       NaN  0.459915  0.301120       NaN       NaN  0.497005
# Shooter            NaN  0.083875  0.238590       NaN       NaN  0.516354
# Simulation         NaN  0.303962  0.315231       NaN       NaN  0.229013
# Sports             NaN  0.380964  0.322537       NaN       NaN  0.203641
# Strategy           NaN  0.219215  0.195896       NaN  0.616863  0.179187
#
# ...

# %%
tmp2.plot(kind = 'box')

# %%
plt.figure(figsize = (15, 6))
sns.violinplot("Genre", "log(Global_Sales)", data = Genre_Rating_GSales)
plt.title('Genre x Global Sales')
# Out:
# Text(0.5,1,'Genre x Global Sales')

# %%
df['log(GSales)'] = df['Global_Sales'].apply(lambda x: np.log(x+1))

# %%
genre_rating_gsales = df[['Genre', 'Rating', 'Global_Sales']]
genre_rating_gsales.head()
# Out:
#           Genre Rating  Global_Sales
# 0        Sports      E         82.53
# 1      Platform    NaN         40.24
# 2        Racing      E         35.52
# 3        Sports      E         32.77
# 4  Role-Playing    NaN         31.37

# %%
grg = genre_rating_gsales.groupby(['Genre', 'Rating'])['Global_Sales'].sum()
grg
# Out:
# Genre         Rating
# Action        AO          1.95
#               E         198.44
#               E10+      219.04
#               EC          0.45
#               M         601.82
#               T         333.76
# Adventure     E          58.01
#               E10+       11.73
#               EC          0.36
#               M          42.15
#               T          19.34
# Fighting      E           1.09
#               E10+        4.56
#               M          28.80
#               T         226.59
# Misc          E         289.39
#               E10+      115.13
#               EC          0.97
#               K-A         1.92
#               M           3.48
#               T         129.78
# Platform      E         329.80
#               E10+       60.63
#               M           1.60
#               T          23.73
# Puzzle        E          88.18
#               E10+       22.33
#               T           2.51
# Racing        E         369.74
# ...

# %%
g = sns.factorplot(x = "Rating", y = "log(GSales)", col = "Genre", data = df, kind = "box", size = 4, aspect = 2)
plt.ylabel('log(Global Sales)')
# Out:
# Text(6328.32,0.5,'log(Global Sales)')

# %% [markdown]
# <b> User Score for each genre

# %%
a = df[['Genre', 'User_Score']]

# %%
g = sns.factorplot("Genre", "Critic_Score", data = df, kind = "box", size = 5, aspect = 3.5)
g.set_axis_labels("Genre", "Total Score")
plt.title("Genre x Total Score")
sns.set(font_scale= 2)

# %%
plt.figure(figsize = (15, 6))
g = sns.stripplot(x='Genre', y = 'Critic_Score', data = df, jitter = True)
plt.ylabel("Critic Score")
plt.xlabel("Genre")
plt.title("Genre x Critic Score")
sns.set(font_scale = 1.5)

# %% [markdown]
# Here, we can see the distributin of Critic Score on each genre of the games.

# %% [markdown]
# <b> Top 5 by Region

# %%
sales_by_region = df[['Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
sbr = sales_by_region.groupby('Publisher')[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum().sort_values(by = 'NA_Sales', ascending = False).head()

# %%
sns.set(font_scale= 1)
sbr.plot(kind = 'bar', subplots = True, layout = (2,2), sharex = True, sharey = True, figsize = (10,6), legend = False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a28fd7a90>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28fca3c8>]], dtype=object)

# %% [markdown]
# <b> Top Video Games and its Sales

# %%
game_sales = df.groupby('Name')['Global_Sales'].sum().sort_values(ascending = False).head(20)

# %%
game_sales.plot(kind = 'bar', figsize = (15, 6))
plt.title("Top Video Game Sales")
plt.xlabel("Video Game")
plt.ylabel("Global_Sales")
# Out:
# Text(0,0.5,'Global_Sales')

# %% [markdown]
# ### Prediction

# %%
clean_df = df.dropna()

# %%
clean_df.shape #Because of large numbers of missing values in the predicted variable, NaNs were dropped
# Out:
# (6825, 17)

# %%
clean_df
# Out:
#                                                Name Platform  Year_of_Release  \
# 0                                        Wii Sports      Wii           2006.0
# 2                                    Mario Kart Wii      Wii           2008.0
# 3                                 Wii Sports Resort      Wii           2009.0
# 6                             New Super Mario Bros.       DS           2006.0
# 7                                          Wii Play      Wii           2006.0
# 8                         New Super Mario Bros. Wii      Wii           2009.0
# 11                                    Mario Kart DS       DS           2005.0
# 13                                          Wii Fit      Wii           2007.0
# 14                               Kinect Adventures!     X360           2010.0
# 15                                     Wii Fit Plus      Wii           2009.0
# 16                               Grand Theft Auto V      PS3           2013.0
# ...

# %%
keep_list = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Critic_Score']
clean2 = clean_df[keep_list]
clean2.head()
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Critic_Score
# 0     41.36     28.96      3.77         8.45          76.0
# 2     15.68     12.76      3.79         3.29          82.0
# 3     15.61     10.93      3.28         2.95          80.0
# 6     11.28      9.14      6.50         2.88          89.0
# 7     13.96      9.18      2.93         2.84          58.0

# %%
import seaborn as sns; sns.set()

sns.pairplot(clean2, hue = 'Critic_Score', size = 3)
#g = sns.pairplot(clean2, hue = 'Critic_Score', size = 3, kind = 'reg')

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.cross_validation import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = LinearRegression(fit_intercept = True)

# %%
clean2.head()
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Critic_Score
# 0     41.36     28.96      3.77         8.45          76.0
# 2     15.68     12.76      3.79         3.29          82.0
# 3     15.61     10.93      3.28         2.95          80.0
# 6     11.28      9.14      6.50         2.88          89.0
# 7     13.96      9.18      2.93         2.84          58.0

# %%
clean2_x = clean2.drop('Critic_Score', axis = 1)
clean2_y = clean2['Critic_Score']
print(clean2_x.shape, clean2_y.shape)
# Out:
# (6825, 4) (6825,)

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(clean2_x, clean2_y, random_state=1)

# %%
Xtrain.head()
# Out:
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 5153       0.30      0.01       0.0         0.05
# 6835       0.21      0.01       0.0         0.02
# 13371      0.03      0.01       0.0         0.00
# 1217       1.26      0.07       0.0         0.21
# 7361       0.10      0.08       0.0         0.03

# %%
Xtest.head()
# Out:
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 461       1.91      0.84      0.00         0.29
# 1926      0.08      0.90      0.04         0.05
# 5114      0.10      0.19      0.02         0.06
# 7228      0.11      0.08      0.00         0.03
# 7971      0.10      0.07      0.00         0.02

# %%
ytrain[:5]
# Out:
# 5153     71.0
# 6835     60.0
# 13371    46.0
# 1217     87.0
# 7361     84.0
# Name: Critic_Score, dtype: float64

# %%
ytest[:5]
# Out:
# 461     75.0
# 1926    76.0
# 5114    84.0
# 7228    66.0
# 7971    74.0
# Name: Critic_Score, dtype: float64

# %%
model.fit(Xtrain, ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.coef_ #coefficient of each variable
# Out:
# array([ 2.39383515,  0.34379985,  1.47576008,  1.59238512])

# %%
model.intercept_ #intercept of slope
# Out:
# 69.182505093528945

# %%
y_model = model.predict(Xtest)

# %%
import math
mse = mean_squared_error(ytest, y_model)
rmse = math.sqrt(mse)

# %%
print("Root mean squared error: %.2f"
      % rmse)
# Out:
# Root mean squared error: 13.47

# %%
print('Variance score: %.2f' % r2_score(ytest, y_model))
# Out:
# Variance score: 0.05

# %% [markdown]
# <b> Trying again but using the log of sales

# %%
log_NA = clean2['NA_Sales'].apply(lambda x: np.log(x+1))
log_EU = clean2['EU_Sales'].apply(lambda x: np.log(x+1))
log_JP = clean2['JP_Sales'].apply(lambda x: np.log(x+1))
log_other = clean2['Other_Sales'].apply(lambda x: np.log(x+1))

# %%
log_df = pd.DataFrame({'log_na': log_NA,
             'log_eu': log_EU,
             'log_jp': log_jp,
             'log_other': log_other})

# %%
log_df['Critic_Score'] = clean2['Critic_Score']

# %%
log_df.head()
# Out:
#      log_eu    log_jp    log_na  log_other  Critic_Score
# 0  3.399863 -3.218876  3.746205   2.246015          76.0
# 2  2.621766 -3.218876  2.814210   1.456287          82.0
# 3  2.479056 -3.218876  2.810005   1.373716          80.0
# 6  2.316488 -3.218876  2.507972   1.355835          89.0
# 7  2.320425 -3.218876  2.705380   1.345472          58.0

# %%
#pairplot to visualise data
sns.pairplot(log_df, hue = 'Critic_Score', size = 3)

# %%
log_df_x = log_df.drop('Critic_Score', axis = 1)
log_df_y = log_df['Critic_Score']
print(log_df_x.shape, log_df_y.shape)
# Out:
# (6825, 4) (6825,)

# %%
model = LinearRegression(fit_intercept = True)

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(log_df_x, log_df_y, random_state=1)

# %%
Xtest.head()
# Out:
#         log_eu    log_jp    log_na  log_other
# 461   0.609766 -3.218876  1.068153   0.254642
# 1926  0.641854 -3.218876  0.076961   0.048790
# 5114  0.173953 -3.218876  0.095310   0.058269
# 7228  0.076961 -3.218876  0.104360   0.029559
# 7971  0.067659 -3.218876  0.095310   0.019803

# %%
model.fit(Xtrain, ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.coef_
# Out:
# array([  8.14160679,   6.69310376,  11.76439881,  -6.36978045])

# %%
model.intercept_
# Out:
# 88.04665152561833

# %% [markdown]
# <b>

# %%
y_model = model.predict(Xtest)

# %%
import math
mse = mean_squared_error(ytest, y_model)
rmse = math.sqrt(mse)

# %%
print("Root mean squared error: %.2f"
      % rmse)
# Out:
# Root mean squared error: 13.14

# %%
print('Variance score: %.2f' % r2_score(ytest, y_model))
# Out:
# Variance score: 0.10

# %% [markdown]
# <b> This only still explains 10% of the data!!! Clearly more work still needs to be done :)
